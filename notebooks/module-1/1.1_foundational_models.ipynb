# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

# model = init_chat_model(model="gpt-5-nano")
model = init_chat_model(
    model="lfm2.5-thinking",
    model_provider="ollama"
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon does not possess a capital city, as it is a natural celestial body without a governing authority or administrative structure. Therefore, the concept of a "capital" does not apply. \n\n\\boxed{No \\ capital}', additional_kwargs={}, response_metadata={'model': 'lfm2.5-thinking', 'created_at': '2026-02-13T13:07:47.422381Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7888565125, 'load_duration': 704496625, 'prompt_eval_count': 17, 'prompt_eval_duration': 538339958, 'eval_count': 892, 'eval_duration': 6502297399, 'logprobs': None, 'model_name': 'lfm2.5-thinking', 'model_provider': 'ollama'}, id='lc_run--019c571d-3b87-7e82-bf8b-7574ec525886-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 892, 'total_tokens': 909})

# %%
print(response.content)
# Out:
# The Moon does not possess a capital city, as it is a natural celestial body without a governing authority or administrative structure. Therefore, the concept of a "capital" does not apply.
#
# \boxed{No \ capital}

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-02-13T13:07:47.422381Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 892,
#  'eval_duration': 6502297399,
#  'load_duration': 704496625,
#  'logprobs': None,
#  'model': 'lfm2.5-thinking',
#  'model_name': 'lfm2.5-thinking',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 17,
#  'prompt_eval_duration': 538339958,
#  'total_duration': 7888565125}

# %% [markdown]
# ## Customising your Model

# %%
#model = init_chat_model(
    #model="gpt-5-nano",
    # Kwargs passed to the model:
    #temperature=1.0
#)

model = init_chat_model(
    model="lfm2.5-thinking",
    model_provider="ollama",
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not have a capital city because it is not a planet or a nation with governance. Like Earth or other celestial bodies, it lacks a capital due to its nature as a natural satellite. If the question assumes a misunderstanding, the answer remains: **no capital exists**. However, if humor or creativity is intended, one might joke about "lunar moons" or "crater capitals," but scientifically, there is no answer. 🌕🌍

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(
    model="lfm2.5-thinking",
    model_provider="ollama"
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not possess a capital city because it is a natural celestial body without a governing authority or political structure. As such, it lacks a capital in the same way Earth or other planets have capitals. Thus, the concept of a "capital" applies only to human-made or political entities.
#
# **Answer:** The Moon does not have a capital city. It is a natural body without a governing structure.
#
# Alternatively, if the question implies a playful twist, one might humorously say there is no capital, but the factual answer is that the Moon lacks one entirely.

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="lfm2.5-thinking")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon does not possess a capital city because it is not a planet or a sovereign nation. As a natural body, it lacks a designated administrative center. Thus, there is no "capital" to reference.
#
# **Answer:** The Moon does not have a capital city. 🌕🌍

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
# agent = create_agent(model="lfm2.5-thinking")

# %%
# agent = create_agent("lfm2.5-thinking")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='ccd30c5c-ae52-4b9f-8bda-6e6b39ff8059'),
#               AIMessage(content='The Moon is a natural satellite of Earth and does not possess a capital city, as it is not part of any nation or organization. Therefore, there is no capital associated with the Moon. \n\n\\boxed{No capital}', additional_kwargs={}, response_metadata={'model': 'lfm2.5-thinking', 'created_at': '2026-02-13T13:17:53.333691Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8632808667, 'load_duration': 39964083, 'prompt_eval_count': 17, 'prompt_eval_duration': 47385208, 'eval_count': 1151, 'eval_duration': 8399958723, 'logprobs': None, 'model_name': 'lfm2.5-thinking', 'model_provider': 'ollama'}, id='lc_run--019c5726-7773-7aa2-b32d-5ed8115a6020-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 1151, 'total_tokens': 1168})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon is a natural satellite of Earth and does not possess a capital city, as it is not part of any nation or organization. Therefore, there is no capital associated with the Moon.
#
# \boxed{No capital}

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='8d7783c4-2683-4c3a-88f2-230bdd5a0701'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='f905fa3c-a133-4339-a9d3-60885a307224', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='87aa5718-3740-48fb-8028-608ecb13e61c'),
#               AIMessage(content='The Moon does not have a capital city because it is a natural celestial body without a centralized government or administrative structure. Unlike planets or other celestial bodies, the Moon lacks a formal governance system, making the concept of a "capital" irrelevant in this context. However, if "Luna City" refers to a fictional or hypothetical location associated with lunar themes, here’s what we can infer:\n\n### Key Points About the Moon:\n1. **Natural Features**: The Moon’s surface is marked by craters, mountains (like the Sea of Tranquility), and maria (dark plains). Regions like the Mare Imbrium or the far side’s highlands hold significant scientific interest.\n2. **Human Exploration**: While no permanent city exists, astronauts and scientists have established temporary bases (e.g., the Lunar Gateway or temporary camps) for research. These are not capitals but logistical hubs.\n3. **Cultural References**: In science fiction or fantasy, "Luna City" might symbolize a utopian settlement on the Moon, often depicted as a hub for space exploration or colonization. Such concepts are speculative but popular in storytelling.\n4. **Moon-Based Cities**: Some speculative ideas envision lunar cities as part of future colonization efforts, though these remain theoretical.\n\nIf "Luna City" refers to a specific fictional or fictionalized concept, further context would be needed to provide details. For now, the Moon’s significance lies in its role as Earth’s natural satellite, offering unique scientific and inspirational value rather than administrative governance. Let me know if you’d like deeper insights into lunar exploration or related topics! 🌕', additional_kwargs={}, response_metadata={'model': 'lfm2.5-thinking', 'created_at': '2026-02-13T13:18:11.514426Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8593470666, 'load_duration': 57616958, 'prompt_eval_count': 45, 'prompt_eval_duration': 132690916, 'eval_count': 1127, 'eval_duration': 8255887849, 'logprobs': None, 'model_name': 'lfm2.5-thinking', 'model_provider': 'ollama'}, id='lc_run--019c5726-bea6-74d2-b080-381d0ea5da3b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 1127, 'total_tokens': 1172})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# **Luna City: The Capital of the Moon**
# As a fictional yet plausible vision of a lunar metropolis, Luna City embodies the aspirations, challenges, and uniqueness of humanity’s foothold on the Moon. While not a real place, it serves as a conceptual hub for space exploration, science, and culture. Below is an exploration of its key aspects:
#
# ---
#
# ### **Geography & Environment**
# - **Location**: Situated on the Moon’s surface near the Shackleton Crater, offering panoramic views of the lunar landscape.
# - **Climate**: Extremely cold (-150°F/-230°C), with thin atmosphere and frequent micrometeorite impacts.
# - **Landmarks**:
#   - **The Citadel**: A towering research tower housing scientific labs and a central government building.
#   - **The Valley of Shadows**: A dark, crater-filled basin used for experimental mining.
#   - **The Solar Oasis**: A geothermal-powered greenhouse sustaining agriculture.
#
# ---
#
# ### **History & Governance**
# - **Founding**: Established in the 22nd century by a coalition of international space agencies and private lunar colonies.
# - **Government**: A hybrid democracy with a lunar council, balancing Earth-based oversight and local autonomy.
# - **Legacy**: A symbol of cooperation amid resource scarcity, often referenced in interplanetary diplomacy.
#
# ---
#
# ### **Culture & Society**
# - **Population**: A mix of Earth-born settlers, lunar-born "Moonborn," and AI-assisted colonists.
# - **Culture**:
#   - **Art**: Space-themed music, poetry, and visual art inspired by lunar landscapes.
#   - **Festivals**: Celebrations of "First Moonlight" (new discoveries) and "Eclipse Nights" (celestial events).
#   - **Traditions**: Lunar "Stargazing Rituals" and "Gravity Dances" to adapt to low-gravity lifestyles.
# - **Language**: A blend of Earth languages with lunar slang (e.g., "gravity" for low gravity, "moonlight" for illumination).
#
# ---
#
# ### **Economy & Industry**
# - **Key Sectors**:
#   - **Resource Extraction**: Mining rare minerals (e.g., helium-3, water ice) for interplanetary trade.
#   - **Tourism**: Luxury stays in lunar hotels and zero-gravity excursions.
#   - **Tech Innovation**: Development of lunar-based robotics and sustainable energy solutions.
# - **Challenges**: High costs of transportation and reliance on Earth for critical supplies.
#
# ---
#
# ### **Science & Research**
# - **Institutions**: Home to the **Lunar Research Institute**, specializing in astrobiology, robotics, and planetary engineering.
# - **Breakthroughs**:
#   - Advanced solar panels for energy efficiency.
#   - Experiments in artificial gravity and radiation shielding.
#   - Collaborations with Earth-based institutions for Earth-Moon symbiosis.
#
# ---
#
# ### **Challenges & Adaptations**
# - **Survival**: Residents adapt to radiation, temperature extremes, and limited resources.
# - **Isolation**: Mental health struggles due to confinement, mitigated by virtual reality and community programs.
# - **Conflict**: Rare but possible tensions over resource allocation or political autonomy.
#
# ---
#
# ### **Role in Humanity**
# - **Symbol of Hope**: A beacon for future colonization and interstellar exploration.
# - **Cultural Hub**: A melting pot of Earth and lunar identities, fostering creativity and resilience.
# - **Ethical Debates**: Discussions on lunar rights, environmental impact, and the ethics of exploiting lunar resources.
#
# ---
#
# ### **Conclusion**
# Luna City embodies the duality of human ambition and vulnerability in the cosmos. While its challenges are immense, it stands as a testament to humanity’s capacity to thrive beyond Earth, shaping the future of space exploration and interplanetary unity. As a fictional yet aspirational concept, it invites imagination while reflecting real-world themes of sustainability, cooperation, and adaptation.
#
# Let me know if you’d like to dive deeper into any specific aspect! 🌕✨
