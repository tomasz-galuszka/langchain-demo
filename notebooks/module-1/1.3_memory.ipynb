# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama

model = ChatOllama(model="lfm2.5-thinking")

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='74f7dfe2-cbc4-4356-9876-fcaf03965636'),
#               AIMessage(content='Hello! It’s wonderful to hear your name is Seán and your favorite color is green. I love learning about your interests and how they shape your world. Feel free to share more about what inspires you, or ask anything—I’m here to help! 😊 Let’s connect and explore together. 🌟  \n\nLet me know how I can assist further!', additional_kwargs={}, response_metadata={'model': 'lfm2.5-thinking', 'created_at': '2026-02-13T14:00:34.092243Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5515840209, 'load_duration': 64703625, 'prompt_eval_count': 21, 'prompt_eval_duration': 58645417, 'eval_count': 703, 'eval_duration': 5299354172, 'logprobs': None, 'model_name': 'lfm2.5-thinking', 'model_provider': 'ollama'}, id='lc_run--019c574d-969e-7111-aace-5add1d3b6365-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 703, 'total_tokens': 724})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='13c9ceb4-752c-4ec3-948b-d73bd9c61c5a'),
#               AIMessage(content='Ah, a question that’s as personal as a coffee cup! While I don’t have a "favorite," many find joy in hues like red, blue, or green—depending on the mood. Or maybe something unexpected, like neon pink or a favorite song’s color! What’s *your* go-to? 😊', additional_kwargs={}, response_metadata={'model': 'lfm2.5-thinking', 'created_at': '2026-02-13T14:00:42.151582Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2694678667, 'load_duration': 66191542, 'prompt_eval_count': 15, 'prompt_eval_duration': 61160000, 'eval_count': 338, 'eval_duration': 2520952954, 'logprobs': None, 'model_name': 'lfm2.5-thinking', 'model_provider': 'ollama'}, id='lc_run--019c574d-c11e-7d02-9055-2415b51d2864-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 338, 'total_tokens': 353})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='9d2c1fe7-36f3-4acb-ab4b-13dc9aca4961'),
#               AIMessage(content='Hello Seán! Your favorite color is green—what a lovely choice! I love sharing green with others too. Enjoy it! 🌿✨', additional_kwargs={}, response_metadata={'model': 'lfm2.5-thinking', 'created_at': '2026-02-13T14:01:16.099273Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4684069167, 'load_duration': 59556125, 'prompt_eval_count': 21, 'prompt_eval_duration': 57187917, 'eval_count': 602, 'eval_duration': 4489512085, 'logprobs': None, 'model_name': 'lfm2.5-thinking', 'model_provider': 'ollama'}, id='lc_run--019c574e-3df5-75d0-9ccb-e8d4d348c9ea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 602, 'total_tokens': 623})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='9d2c1fe7-36f3-4acb-ab4b-13dc9aca4961'),
#               AIMessage(content='Hello Seán! Your favorite color is green—what a lovely choice! I love sharing green with others too. Enjoy it! 🌿✨', additional_kwargs={}, response_metadata={'model': 'lfm2.5-thinking', 'created_at': '2026-02-13T14:01:16.099273Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4684069167, 'load_duration': 59556125, 'prompt_eval_count': 21, 'prompt_eval_duration': 57187917, 'eval_count': 602, 'eval_duration': 4489512085, 'logprobs': None, 'model_name': 'lfm2.5-thinking', 'model_provider': 'ollama'}, id='lc_run--019c574e-3df5-75d0-9ccb-e8d4d348c9ea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 602, 'total_tokens': 623}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='88058f4c-e697-4027-a782-f9c4c257b660'),
#               AIMessage(content='Your favorite color is **green**! 🌿 It’s a classic choice that brings joy and vibrancy. Enjoy it wherever it brings you happiness! 😊 Let me know if you’d like more tips!', additional_kwargs={}, response_metadata={'model': 'lfm2.5-thinking', 'created_at': '2026-02-13T14:01:30.47816Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5788047916, 'load_duration': 53796041, 'prompt_eval_count': 68, 'prompt_eval_duration': 69775000, 'eval_count': 745, 'eval_duration': 5564714543, 'logprobs': None, 'model_name': 'lfm2.5-thinking', 'model_provider': 'ollama'}, id='lc_run--019c574e-71d0-7830-9064-6da7eef4ec1d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 68, 'output_tokens': 745, 'total_tokens': 813})]}
